# %%
import numpy as np
import pandas as pd

# %%
m1=pd.read_csv('3.2.1PandaMovies.csv')
m1.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
m1.shape
# Out:
# (979, 6)

# %%
m1.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
m1.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
m1.content_rating.unique()
# Out:
# array(['R', 'PG-13', 'NOT RATED', 'PG', 'UNRATED', 'APPROVED', 'PASSED',
#        'G', 'X', nan, 'TV-MA', 'GP', 'NC-17'], dtype=object)

# %%
m1['genre'].unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
m1.genre.nunique()
# Out:
# 16

# %%
m1.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
m1.actors_list[0]
# Out:
# "[u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton']"

# %%
m1[(m1.genre=='Drama') & (m1.duration>200)]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
m1.title.str.upper().head()
# Out:
# 0    THE SHAWSHANK REDEMPTION
# 1               THE GODFATHER
# 2      THE GODFATHER: PART II
# 3             THE DARK KNIGHT
# 4                PULP FICTION
# Name: title, dtype: object

# %%
m1[m1.title.str.contains('godfather', case=False)]
# Out:
#      star_rating                    title content_rating  genre  duration  \
# 1            9.2            The Godfather              R  Crime       175
# 2            9.1   The Godfather: Part II              R  Crime       200
# 711          7.6  The Godfather: Part III              R  Crime       162
#
#                                            actors_list
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 711    [u'Al Pacino', u'Diane Keaton', u'Andy Garcia']

# %%
m1[m1.title.str.contains('Dark',case=False)]
# Out:
#      star_rating                    title content_rating    genre  duration  \
# 3            9.0          The Dark Knight          PG-13   Action       152
# 43           8.5    The Dark Knight Rises          PG-13   Action       165
# 218          8.1             Donnie Darko              R    Drama       113
# 324          8.0       Dancer in the Dark              R    Crime       140
# 488          7.8  Star Trek Into Darkness          PG-13   Action       132
# 583          7.8                Dark City              R  Mystery       100
# 738          7.6         Army of Darkness              R   Comedy        81
# 955          7.4         Zero Dark Thirty              R    Drama       157
#
#                                            actors_list
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 43   [u'Christian Bale', u'Tom Hardy', u'Anne Hatha...
# 218  [u'Jake Gyllenhaal', u'Jena Malone', u'Mary Mc...
# 324  [u'Bj\xf6rk', u'Catherine Deneuve', u'David Mo...
# ...

# %%
m1[m1.star_rating.between(8,9)]
# Out:
#      star_rating                                              title  \
# 3            9.0                                    The Dark Knight
# 4            8.9                                       Pulp Fiction
# 5            8.9                                       12 Angry Men
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 8            8.9                                   Schindler's List
# 9            8.9                                         Fight Club
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 11           8.8                                          Inception
# 12           8.8     Star Wars: Episode V - The Empire Strikes Back
# 13           8.8                                       Forrest Gump
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# ...

# %%
m1[m1.star_rating.between(8,9)].count()
# Out:
# star_rating       391
# title             391
# content_rating    390
# genre             391
# duration          391
# actors_list       391
# dtype: int64

# %%
m1.star_rating.max()
# Out:
# 9.3

# %%
m1.star_rating.aggregate(['min','max','mean'])
# Out:
# min     7.400000
# max     9.300000
# mean    7.889785
# Name: star_rating, dtype: float64

# %%
m1.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
#Top 5 movies with longest duration displaying title and duration as a DataFrame
m2=m1.sort_values('duration',ascending=False)[:5]
m2[['title','duration']]
# Out:
#                                  title  duration
# 476                             Hamlet       242
# 157                 Gone with the Wind       238
# 78         Once Upon a Time in America       229
# 142  Lagaan: Once Upon a Time in India       224
# 445               The Ten Commandments       220
